# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnMarie9/Qm206-Ann-/blob/main/Taller_SURFACE_PLOTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TALLER: SURFACE PLOTS
# Utilizar el código anterior para generar las gráficas correspondientes a las siguientes funciones
# *   $z=sin(\sqrt{x^2+y^2}) $
# *    $z=(x-1)^2(x+1)^2 + (y-1)^2(y+1)^2$

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Función z = sin(sqrt(x^2 + y^2))
def z_function(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# %%
# Datos para x, y y z
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x_grid, y_grid = np.meshgrid(x, y)
z = z_function(x_grid, y_grid)

# %%
# Gráfica de contorno
contours = plt.contour(x_grid, y_grid, z)
plt.clabel(contours)
plt.title('Contour Plot')
plt.show()

# %%
# Gráfica de contorno con nivel de colores y mapa de colores
color_niveles = np.linspace(-1, 1, 20)
contours = plt.contour(x_grid, y_grid, z, levels=color_niveles, colors="black")
plt.clabel(contours)
plt.contourf(x_grid, y_grid, z, levels=color_niveles, cmap='viridis')  # Puedes cambiar 'viridis' por otro mapa de colores
plt.colorbar()
plt.title('Contour Plot with Colored Levels')
plt.show()

# %%
# Función z
def func_z(x, y):
    return (x - 1)**2 * (x + 1)**2 + (y - 1)**2 * (y + 1)**2

# %%
# Puntos
x_grid, y_grid = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-3, 3, 100))

# %%
# Función z en los puntos de la malla
z = func_z(x_grid, y_grid)

# %%
# Gráficas de contorno y de contorno relleno
contours = plt.contour(x_grid, y_grid, z, colors="black")
plt.clabel(contours)
# Out:
# <a list of 7 text.Text objects>

# %%
color_niveles = np.linspace(np.min(z), np.max(z), 20)
contours = plt.contour(x_grid, y_grid, z, levels=color_niveles, colors="black")
plt.clabel(contours)
plt.contourf(x_grid, y_grid, z, levels=color_niveles)
plt.colorbar()
plt.show()
