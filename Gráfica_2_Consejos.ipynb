# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnMarie9/Qm206-Ann-/blob/main/Gr%C3%A1fica_2_Consejos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre="Ann"
apellido="Pinto"
cédula="4-821-1964"
n=apellido+","+nombre
print(n)
print(cédula)
# Out:
# Pinto,Ann
# 4-821-1964

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Consejos=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
Consejos
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x="total_bill", y="tip", hue="smoker", data=Consejos, palette="Set2")
plt.title("Encuesta: Tú Fumas")
# Out:
# Text(0.5, 1.0, 'Encuesta: Tú Fumas')
