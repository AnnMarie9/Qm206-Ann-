# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnMarie9/Qm206-Ann-/blob/main/Gr%C3%A1fica_3_puntos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre="Ann"
apellido="Pinto"
cédula="4-821-1964"
n=apellido+","+nombre
print(n)
print(cédula)
# Out:
# Pinto,Ann
# 4-821-1964

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
puntos=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/dots.csv")
puntos
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
sns.catplot(data=puntos, kind="violin", x="choice", y="time", hue="coherence", palette="Set2")
plt.title("T vs C")
# Out:
# Text(0.5, 1.0, 'T vs C')
