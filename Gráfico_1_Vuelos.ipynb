# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnMarie9/Qm206-Ann-/blob/main/Gr%C3%A1fico_1_Vuelos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre="Ann"
apellido="Pinto"
cédula="4-821-1964"
n=apellido+","+nombre
print(n)
print(cédula)
# Out:
# Pinto,Ann
# 4-821-1964

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vuelos=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/flights.csv")
vuelos
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
sns.boxplot(x="year",y="passengers",data=vuelos,palette="Set1")
plt.title("Población Transportada Por American Airlines")
# Out:
# Text(0.5, 1.0, 'Población Transportada Por American Airlines')
